# %% [markdown]
# ## N-gram basert på dewey

# %%
import dhlab.nbtext as nb
import pandas as pd
import dhlab.module_update as mu

# %%
mu.css()
# Out:
# <style>@import url(
# http://fonts.googleapis.com/css?family=Lato|Philosopher|Montserrat|Source+Code+Pro|Istok+Web|Philosopher|Assistant:200,400,700);
#
# /*
# #notebook-container {
# 	-webkit-box-shadow: none;
# 	box-shadow: none;
# }
# */
#
# h1, h2, h3, h4, h5, h6 {
# 	font-family: 'Montserrat', sans-serif;
# 	line-height: 2em;
#     color: #004f99;
#     font-weight: 600;
# }
#
# h1 { font-size: 4.5em; }
# h2 { font-size: 4em; }
# h3 { font-size: 3.5em; }
# h4 { font-size: 3em; }
# h5 { font-size: 2.5em; color:DarkSlateGray; }
# h6 { font-size: 2em; }
#
# p {
# 	font-family: 'Assistant', sans-serif;
# 	font-size: 1.2em;
# 	line-height: 1.4em;
# 	color: black;
# }
# p code {
# 	font-size:0.9em;
# }
# div.input_area {
# 	border:none !important;
# 	border-left:1px solid #ff851b !important
# }
#
# span.cm-keyword {
# 	color:#339966 !important;
# }
# span.nn {  /*span.cm-variable, span.cm-property*/
# 	color: #3399ff !important;
# }
# div.CodeMirror {
# 	font-family: 'Inconsolata', monospace;
# 	font-size: 1.1em;
#
# }
# </style>

# %%
nb.dewey('610')
# Out:
# {'1': ['6', 'Teknologi'],
#  '2': ['61', 'Medisin og helse'],
#  '3': ['610', 'Medisin og helse']}

# %% [markdown]
# # Råfrekvenser unigram

# %%
nb.unigram('meslinger', ddk="61%").plot(lw=4, figsize=(10,5))

# %% [markdown]
# # Bigram

# %%
nb.bigram('meslinger','og').plot()

# %%
kohort_acc = "meg ham deg oss dem dere henne hverandre"
kohort = "jeg du han hun vi de"

# %%
def uni(x):
    df = nb.unigram(x, period=(1930, 2010))
    df.columns = [x]
    return df

# %%
def compare(kohort):
    df = pd.concat(map(uni, kohort), axis=1)
    dfsum = df.sum(axis=1)
    return pd.concat([ (df[x]/(dfsum)).rename(x) for x in df], axis=1)

# %%
comp_kohort = compare(kohort.split())

# %%
comp_acc = compare(kohort_acc.split())

# %%
comp_acc.plot(figsize = (10,8), lw = 4, alpha=.6)

# %%
c = lambda x: pd.concat([nb.frame(nb.unigram(w, period=(1600, 2000)), w) for w in [y.strip() for y in x.split(",")]], axis=1)

# %%
c('neger, negre').plot()

# %%
- Hødnebø 1960 (Norske diplomer til og med år 1300),
- Hødnebø 1966 (Utvalg av norske diplomer 1350--1550),
- Rindal og Halvorsen 2009 (Middelalderbrev fra Ringerike 1263--1570).

# %%
nb.book_urn(author = "%HALVORSE%rindal%")
# Out:
# []

# %%
urns = [2009090904028,2011031520003,2016011948059]

# %%
nb.metadata(urns)
# Out:
# [[2009090904028,
#   '',
#   1960,
#   'Norske diplomer til og med år 1300',
#   '',
#   'Selskapet til utgivelse av gamle norske håndskrifter',
#   'notfiction',
#   '654f28fb0a30617ed98e1a6d4776b66c',
#   'mul',
#   ''],
#  [2016011948059,
#   '',
#   2009,
#   'Middelalderbrev fra Ringerike 1263-1570',
#   'originaltekster med oversettelse til moderne norsk',
#   'Kolltopp forl.',
#   'notfiction',
#   'abd2091d1098a8e63691c7a63e921b93',
#   'nob',
#   '']]

# %%
nb.urn_concordance(urns=urns, word="kirken", size=20)
# Out:
# <table><tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2009090904028?searchText=kirken' target='_blank' style='text-decoration:none'>Norske diplomer til og med år 1300, , 1960</a>
#                 </td>
#                 <td>minst kampen og uroen innen</td>
#                 <td>kirken</td>
#                 <td style='text-align:left'>selv .</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2009090904028?searchText=kirken' target='_blank' style='text-decoration:none'>Norske diplomer til og med år 1300, , 1960</a>
#                 </td>
#                 <td>herre Bjarne Erlingssons framferd mot</td>
#                 <td>kirken</td>
#                 <td style='text-align:left'>. Herre Bjarne hadde gått</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2009090904028?searchText=kirken' target='_blank' style='text-decoration:none'>Norske diplomer til og med år 1300, , 1960</a>
#                 </td>
#                 <td>11 ) , nemlig at</td>
#                 <td>kirken</td>
#                 <td style='text-align:left'>skulle få sine tiender og</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2009090904028?searchText=kirken' target='_blank' style='text-decoration:none'>Norske diplomer til og med år 1300, , 1960</a>
#                 </td>
#                 <td>av brevene vedrører innbyrdes-striden i</td>
#                 <td>kirken</td>
#                 <td style='text-align:left'>, den slo ut særlig</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2009090904028?searchText=kirken' target='_blank' style='text-decoration:none'>Norske diplomer til og med år 1300, , 1960</a>
#                 </td>
#                 <td>, nå er kommet under</td>
#                 <td>kirken</td>
#                 <td style='text-align:left'>, og forbyr bøndene på</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2009090904028?searchText=kirken' target='_blank' style='text-decoration:none'>Norske diplomer til og med år 1300, , 1960</a>
#                 </td>
#                 <td>i Oslo , mot at</td>
#                 <td>kirken</td>
#                 <td style='text-align:left'>får en del andre gårder</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2009090904028?searchText=kirken' target='_blank' style='text-decoration:none'>Norske diplomer til og med år 1300, , 1960</a>
#                 </td>
#                 <td>til korsbrødrene å rå for</td>
#                 <td>kirken</td>
#                 <td style='text-align:left'>under erkestolens vakans .</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2009090904028?searchText=kirken' target='_blank' style='text-decoration:none'>Norske diplomer til og med år 1300, , 1960</a>
#                 </td>
#                 <td>med en halvdel hver til</td>
#                 <td>kirken</td>
#                 <td style='text-align:left'>og korsbrødrene , for at</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2009090904028?searchText=kirken' target='_blank' style='text-decoration:none'>Norske diplomer til og med år 1300, , 1960</a>
#                 </td>
#                 <td>ved Laf r anz -</td>
#                 <td>kirken</td>
#                 <td style='text-align:left'>i Tønsberg , gir en</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2009090904028?searchText=kirken' target='_blank' style='text-decoration:none'>Norske diplomer til og med år 1300, , 1960</a>
#                 </td>
#                 <td>, hadde skjenket jorda til</td>
#                 <td>kirken</td>
#                 <td style='text-align:left'>, og mot at gårdens</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2009090904028?searchText=kirken' target='_blank' style='text-decoration:none'>Norske diplomer til og med år 1300, , 1960</a>
#                 </td>
#                 <td>hadde testamentert av gården Vollißennebutil</td>
#                 <td>kirken</td>
#                 <td style='text-align:left'>og korsbrødrene .</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2009090904028?searchText=kirken' target='_blank' style='text-decoration:none'>Norske diplomer til og med år 1300, , 1960</a>
#                 </td>
#                 <td>i Lom ) mot at</td>
#                 <td>kirken</td>
#                 <td style='text-align:left'>får det samme i Øfragarde.</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2009090904028?searchText=kirken' target='_blank' style='text-decoration:none'>Norske diplomer til og med år 1300, , 1960</a>
#                 </td>
#                 <td>kongens påsyn , og gir</td>
#                 <td>kirken</td>
#                 <td style='text-align:left'>rett til de bøter og</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2009090904028?searchText=kirken' target='_blank' style='text-decoration:none'>Norske diplomer til og med år 1300, , 1960</a>
#                 </td>
#                 <td>communem mensam Ca- | nonicorum</td>
#                 <td>kirken</td>
#                 <td style='text-align:left'>paa Houg 1267. Confirme- |</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2009090904028?searchText=kirken' target='_blank' style='text-decoration:none'>Norske diplomer til og med år 1300, , 1960</a>
#                 </td>
#                 <td>kirke at Vi ga til</td>
#                 <td>kirken</td>
#                 <td style='text-align:left'>2 markebol i disse eiendommer</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2009090904028?searchText=kirken' target='_blank' style='text-decoration:none'>Norske diplomer til og med år 1300, , 1960</a>
#                 </td>
#                 <td>Frosta . Disse eiendommene skal</td>
#                 <td>kirken</td>
#                 <td style='text-align:left'>evinnelig eie til evig odel</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2009090904028?searchText=kirken' target='_blank' style='text-decoration:none'>Norske diplomer til og med år 1300, , 1960</a>
#                 </td>
#                 <td>de til evig tid mens</td>
#                 <td>kirken</td>
#                 <td style='text-align:left'>står holde oppe vår årtid</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2009090904028?searchText=kirken' target='_blank' style='text-decoration:none'>Norske diplomer til og med år 1300, , 1960</a>
#                 </td>
#                 <td>Det skal også ringes fra</td>
#                 <td>kirken</td>
#                 <td style='text-align:left'>og i hele byen ved</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2009090904028?searchText=kirken' target='_blank' style='text-decoration:none'>Norske diplomer til og med år 1300, , 1960</a>
#                 </td>
#                 <td>styrke den [ d :</td>
#                 <td>kirken</td>
#                 <td style='text-align:left'>] til alt som rett</td>
#             </tr>
# <tr>
#                 <td>
